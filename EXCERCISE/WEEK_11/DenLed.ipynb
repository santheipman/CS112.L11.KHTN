# %% [markdown]
# <a href="https://colab.research.google.com/github/santheipman/CS112.L11.KHTN/blob/master/DenLed.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <img src="https://www.uit.edu.vn/sites/vi/files/banner.png" alt="UIT logo" class="left">
# <h1 align= "center">   <strong>     CS112.PHÂN TÍCH VÀ THIẾT KẾ THUẬT TOÁN</strong> </h1>

# %% [markdown]
# # **CS112.L11.KHTN**
# ## **NHÓM 5**
#
# |  STT | HỌ TÊN             | MSSV     | VAI TRÒ     | LIÊN HỆ |
# |---|--------------------|-----------------|----------------|---------|
# |**1** | **VŨ QUÍ SAN**         | **18520143** | **NHÓM TRƯỞNG** |[**GitHub**](https://github.com/santheipman) **và** **Gmail**: 18520143@gm.uit.edu.vn          |
# | **2** | **PHẠM MẠNH TIẾN**     | **18520166**| **THÀNH VIÊN**  | [**GitHub**](https://github.com/tienpm) **và** **Gmail**: 18520166@gm.uit.edu.vn        |
# | **3** |**NGUYỄN VƯƠNG THỊNH** | **18520367** | **THÀNH VIÊN**  |  [**GitHub**](https://github.com/ThinhNguyen209) **và** **Gmail**: 18520367@gm.uit.edu.vn      |

# %% [markdown]
# ## **ĐỀ BÀI**
#
# ### **ĐÈN LED**
#
# <p style="text-align:justify">Alice vừa ho&agrave;n th&agrave;nh một hợp đồng lắp bảng hiển thị số bằng đ&egrave;n LED. Mỗi chữ số được hiển thị trong một khung chữ nhật với 7 ống đ&egrave;n LED. Bằng c&aacute;ch bật c&aacute;c ống đ&egrave;n LED th&iacute;ch hợp ta c&oacute; thể hiển thị chữ số bất kỳ. Số đ&egrave;n s&aacute;ng c&agrave;ng nhiều th&igrave; việc hiển thị chữ số đ&oacute; c&agrave;ng tốn năng lượng. V&iacute; dụ, hiển thị chữ số 9 sẽ tốn năng lượng hơn hiển thị chữ số 7.</p>
#
# <p style="text-align:justify"><img src="data:image/png;base64,..." style="margin-left:100px; margin-right:100px" /></p>
#
# <p style="text-align:justify">Sau khi b&agrave;n giao sản phẩm trong tay Alice c&ograve;n thừa lại một số kh&aacute; nhiều c&aacute;c khung hiển thị số v&agrave; một cục pin nguồn. Dung lượng pin cho ph&eacute;p bật s&aacute;ng <strong><em>n</em></strong> ống đ&egrave;n LED. Alice muốn d&ugrave;ng pin bật đ&uacute;ng <strong><em>n</em></strong> ống đ&egrave;n để hiển thị một số v&agrave; số hiển thị được phải c&oacute; tổng chữ số l&agrave; lớn nhất.</p>
#
# <p style="text-align:justify">H&atilde;y x&aacute;c định tổng lớn nhất của c&aacute;c chữ số của số c&oacute; thể bật s&aacute;ng.</p>
#
# <p style="text-align:justify"><strong><em>Dữ liệu:</em></strong> V&agrave;o từ thiết bị nhập chuẩn gồm một d&ograve;ng chứa số nguy&ecirc;n <strong><em>n</em></strong> (2 &le; <strong><em>n</em></strong> &le; 10<sup>6</sup>).</p>
#
# <p style="text-align:justify"><strong><em>Kết quả:</em></strong> Đưa ra thiết bị xuất chuẩn một số nguy&ecirc;n &ndash; tổng lớn nhất đạt được.</p>
#
# <p><strong><em>V&iacute; dụ:</em></strong></p>
#
# <table border="1" cellspacing="0">
# 	<tbody>
# 		<tr>
# 			<td style="background-color:#fff2cc; border-color:black; width:85.5pt">
# 			<p style="text-align:center"><strong><tt>INPUT</tt></strong></p>
# 			</td>
# 			<td style="width:40.5pt">
# 			<p style="text-align:center">&nbsp;</p>
# 			</td>
# 			<td style="background-color:#fff2cc; border-color:black; width:99.0pt">
# 			<p style="text-align:center"><strong><tt>OUTPUT</tt></strong></p>
# 			</td>
# 		</tr>
# 		<tr>
# 			<td style="background-color:#fff2cc; border-color:black; height:21.55pt; width:85.5pt">
# 			<p><strong><tt><span style="color:#333333">7</span></tt></strong></p>
# 			</td>
# 			<td style="height:21.55pt; vertical-align:bottom; width:40.5pt">
# 			<p style="text-align:center">&nbsp;</p>
# 			</td>
# 			<td style="background-color:#fff2cc; height:21.55pt; width:99.0pt">
# 			<p><strong><tt><span style="color:#333333">11</span></tt></strong></p>
# 			</td>
# 		</tr>
# 	</tbody>
# </table>

# %% [markdown]
# ## **1. Tóm tắt bài toán**

# %% [markdown]
# Cho số nguyên **n**. Xác định tổng các chữ số  lớn nhất **x** tạo thành từ số  được tạo bởi đúng **n** đoạn đèn led của led 7 đoạn

# %% [markdown]
# ## **2. Nhận dạng mẫu (Pattern-Recognition)**

# %% [markdown]
# Sắp xếp các chứ số của led 7 đoạn ta được:
# - số 1 - sử dụng 2 đoạn
# - số 2 - sử dụng 5 đoạn
# - số 3 - sử dụng 5 đoạn
# - số 4 - sử dụng 4 đoạn
# - số 5 - sử dụng 5 đoạn
# - số 6 - sử dụng 6 đoạn
# - số 7 - sử dụng 3 đoạn
# - số 8 - sử dụng 7 đoạn
# - số 9 - sử dụng 6 đoạn
#
# Ta thấy số 7 chữ số lớn nhất sử dụng ít đoạn đèn led nhất. Nên ta có thể giải quyết bài toán theo giải thuật tham lam

# %% [markdown]
# ## **3. Thuật toán**
#
# ### **3.1. Ý tưởng**
#
# - Tìm số dư **r** của phép chia **n** / 3
# - Nếu **r** = 0 thì kết quả là 7 * (n div 3)
# - Nếu **r** = 1 thì kết quả thì 7 * (n div 3) trừ đi 1 số 7 để được phần dư là 4 đoạn và ta có thể cộng thêm số 4
# - Nếu **r** = 2 thì kết quả là 7 * (n div 3) + số 1 (sử dụng đúng 2 đoạn đèn led dư)
#
#
# ### **3.2. Mã giả thuật toán**
#
# ```pseudocode
#
# Initialize n
# ans = 7 * (n div 3)
# if n mod 3 == 1 then
#     ans = ans - 7 + 4
# if n mod 3 == 2 then
#     ans = ans + 1
#
# Return ans
# ```

# %% [markdown]
# ## **4. Cài đặt**

# %%
n = int(input())
ans = 7 * (n // 3)
if n % 3 == 1:
  ans = ans - 7 + 4
if n % 3 == 2:
  ans = ans + 1

print(ans)
# Out:
# 7
# 11

# %% [markdown]
# ## **5. Kết quả trên Wecode**

# %% [markdown]
# ![image.png](data:image/png;base64,...)
